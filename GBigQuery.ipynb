# %%
pip install pandas-gbq -U

# %%
import pandas_gbq

# %%
project_id = 'XXXXXXXXXXXXXXX' # TODO: replace with your own!

sql = """
SELECT faa_identifier, name, longitude, latitude, airport_type, service_city, country
FROM `bigquery-public-data.faa.us_airports`
WHERE airport_use = 'Public'
"""
airports_df = pandas_gbq.read_gbq(sql, project_id=project_id)

# %%
airports_df
# Out:
#      faa_identifier               name   longitude   latitude airport_type  \
# 0               HYG           Hydaburg -132.828332  55.206321      Seaport
# 1               MTM         Metlakatla -131.578086  55.131050      Seaport
# 2               AQC            Klawock -133.101712  55.554662      Seaport
# 3               ELV         Elfin Cove -136.347413  58.195188      Seaport
# 4               FNR         Funter Bay -134.897927  58.254390      Seaport
# ...             ...                ...         ...        ...          ...
# 5363            W99           Grant Co  -79.145864  38.994952     Aerodome
# 5364            82V   Pine Bluffs Muni -104.134760  41.152479     Aerodome
# 5365            46U             Alpine -111.038512  43.181812     Aerodome
# 5366            U68  North Big Horn Co -108.445512  44.911673     Aerodome
# 5367            W43        Hulett Muni -104.567844  44.662868     Aerodome
#
#              service_city        country
# 0                Hydaburg  United States
# 1              Metlakatla  United States
# 2                 Klawock  United States
# 3              Elfin Cove  United States
# 4              Funter Bay  United States
# ...                   ...            ...
# 5363           Petersburg  United States
# 5364          Pine Bluffs  United States
# 5365               Alpine  United States
# 5366  Cowley/Lovell/Byron  United States
# 5367               Hulett  United States
#
# [5368 rows x 7 columns]
